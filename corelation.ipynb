# %% [markdown]
# <a href="https://colab.research.google.com/github/MalkitPhogat/Reinforcement_learning/blob/main/corelation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from numpy import random
import seaborn as sns
import matplotlib.pyplot as plt
import random
np.random.seed(1)

# %%
x = np.array([1,2,3,4,5])
y = np.array([2,4,6,8,10])

# %%
x = np.random.randint(0, 50, 1000)

# %%
y = x + np.random.normal(0, 10, 1000)
y = x + np.random.normal(0, 10, 1000)

# %%
plt.scatter(x,y)
print(np.corrcoef(x,y))
plt.show()
# Out:
# [[1. 1.]
#  [1. 1.]]

# %%
# %matplotlib inline
plt.style.use('ggplot')

plt.scatter(x, y)
plt.show()

# %%
p = np.array([1,2,3,4,5])
q = np.array([5,4,3,2,1])

# %%
plt.scatter(p,q)
print(np.corrcoef(p,q))
plt.show()
# Out:
# [[ 1. -1.]
#  [-1.  1.]]

# %%
x = np.random.randint(0, 50, 1000)
y = 100 - x + np.random.normal(0, 5, 1000)
np.corrcoef(x, y)
# Out:
# array([[ 1.        , -0.94551069],
#        [-0.94551069,  1.        ]])

# %%
plt.scatter(x, y)
plt.show()

# %%
p1 = np.array([1,8,35,14,5])
q2 = np.array([5,34,73,22,11])

# %%
plt.scatter(p1,q2)
print(np.corrcoef(p1,q2))
plt.show()
# Out:
# [[1.         0.94693346]
#  [0.94693346 1.        ]]

# %%
x = np.random.randint(0, 50, 1000)
y = np.random.randint(0, 50, 1000)

np.corrcoef(x, y)
# Out:
# array([[ 1.        , -0.04530009],
#        [-0.04530009,  1.        ]])

# %%
plt.scatter(x, y)
plt.show()

# %%
import pandas as pd

df = pd.DataFrame({'a': np.random.randint(0, 50, 1000)})
df['b'] = df['a'] + np.random.normal(0, 10, 1000)
df['c'] = 100 - df['a'] + np.random.normal(0, 5, 1000)
df['d'] = np.random.randint(0, 50, 1000)

df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.808447 -0.949575 -0.009126
# b  0.808447  1.000000 -0.756525 -0.008926
# c -0.949575 -0.756525  1.000000  0.002464
# d -0.009126 -0.008926  0.002464  1.000000

# %%
pd.plotting.scatter_matrix(df, figsize=(6, 6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)), df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar()
plt.show()
